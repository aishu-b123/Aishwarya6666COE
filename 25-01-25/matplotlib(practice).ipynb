# %%
import pandas as pd 
df=pd.read_csv("C:\\Users\\CVR\\Desktop\\6666coe\\Aishwarya6666COE\\climate\\GlobalLandTemperaturesByCity.csv")
df.head(20)
# Out:
#             dt  AverageTemperature  AverageTemperatureUncertainty   City  \
# 0   1743-11-01               6.068                          1.737  Århus
# 1   1743-12-01                 NaN                            NaN  Århus
# 2   1744-01-01                 NaN                            NaN  Århus
# 3   1744-02-01                 NaN                            NaN  Århus
# 4   1744-03-01                 NaN                            NaN  Århus
# 5   1744-04-01               5.788                          3.624  Århus
# 6   1744-05-01              10.644                          1.283  Århus
# 7   1744-06-01              14.051                          1.347  Århus
# 8   1744-07-01              16.082                          1.396  Århus
# 9   1744-08-01                 NaN                            NaN  Århus
# 10  1744-09-01              12.781                          1.454  Århus
# 11  1744-10-01               7.950                          1.630  Århus
# ...

# %%
df['Country'].unique()
# Out:
# array(['Denmark', 'Turkey', 'Kazakhstan', 'China', 'Spain', 'Germany',
#        'Nigeria', 'Iran', 'Russia', 'Canada', "Côte D'Ivoire",
#        'United Kingdom', 'Saudi Arabia', 'Japan', 'United States',
#        'India', 'Benin', 'United Arab Emirates', 'Mexico', 'Venezuela',
#        'Ghana', 'Ethiopia', 'Australia', 'Yemen', 'Indonesia', 'Morocco',
#        'Pakistan', 'France', 'Libya', 'Burma', 'Brazil', 'South Africa',
#        'Syria', 'Egypt', 'Algeria', 'Netherlands', 'Malaysia', 'Portugal',
#        'Ecuador', 'Italy', 'Uzbekistan', 'Philippines', 'Madagascar',
#        'Chile', 'Belgium', 'El Salvador', 'Romania', 'Peru', 'Colombia',
#        'Tanzania', 'Tunisia', 'Turkmenistan', 'Israel', 'Eritrea',
#        'Paraguay', 'Greece', 'New Zealand', 'Vietnam', 'Cameroon', 'Iraq',
#        'Afghanistan', 'Argentina', 'Azerbaijan', 'Moldova', 'Mali',
#        'Congo (Democratic Republic Of The)', 'Thailand',
# ...

# %%
df.isna().sum()
# Out:
# dt                                    0
# AverageTemperature               364130
# AverageTemperatureUncertainty    364130
# City                                  0
# Country                               0
# Latitude                              0
# Longitude                             0
# dtype: int64

# %%
df.shape
# Out:
# (8599212, 7)

# %%
df.dtypes
# Out:
# dt                                object
# AverageTemperature               float64
# AverageTemperatureUncertainty    float64
# City                              object
# Country                           object
# Latitude                          object
# Longitude                         object
# dtype: object

# %%
df['dt']=pd.to_datetime(df['dt'])

# %%
import matplotlib.pyplot as plt
temp=df[df['City']=='Århus']
temp['year'] = temp['dt'].dt.year
x = temp['year']
y = temp['AverageTemperature']
plt.plot(x, y)
plt.xlabel('Year')
plt.ylabel('Average Temperature')
plt.title('Average Temperature over Years')
plt.show()
# Out:
# C:\Users\CVR\AppData\Local\Temp\ipykernel_14184\265039171.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp['year'] = temp['dt'].dt.year

# %%
df['dt'] = pd.to_datetime(df['dt'])
df_cleaned = df.dropna(subset=['AverageTemperature'])
df_cleaned['Year'] = df_cleaned['dt'].dt.year
city = 'Århus'
city_data = df_cleaned[df_cleaned['City'] == city]
avg_temp_city = city_data.groupby('Year')['AverageTemperature'].mean()
plt.figure(figsize=(10, 6))
avg_temp_city.plot(kind='line', color='blue', linewidth=2)
plt.title('Average Temperature Per Year', fontsize=16)
plt.xlabel('Year', fontsize=14)
plt.ylabel('Average Temperature (°C)', fontsize=14)
plt.show()
# Out:
# C:\Users\CVR\AppData\Local\Temp\ipykernel_14184\18081935.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_cleaned['Year'] = df_cleaned['dt'].dt.year

# %%
import matplotlib.pyplot as plt
temp=df[df['City']=='Çorum']
temp['year'] = temp['dt'].dt.year
temp['AverageTemperature']=temp['AverageTemperature'].fillna(temp['AverageTemperature'].mean())
avg_temp_city = temp.groupby('year')['AverageTemperature'].mean()
print(avg_temp_city.head())
plt.figure(figsize=(12,6))
plt.plot(avg_temp_city.index,avg_temp_city.values)
plt.xlabel('Year')
plt.ylabel('Average Temperature')
plt.title('Average Temperature over Years')
plt.show()
# Out:
# year
# 1753     9.849250
# 1754    10.066750
# 1755     9.836000
# 1756    10.560750
# 1757    10.398583
# Name: AverageTemperature, dtype: float64
# C:\Users\CVR\AppData\Local\Temp\ipykernel_14184\3419505146.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp['year'] = temp['dt'].dt.year
# C:\Users\CVR\AppData\Local\Temp\ipykernel_14184\3419505146.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %%
import matplotlib.pyplot as plt
temp_country=df[df['Country'].isin(['Denmark','Turkey'])]
temp_country['AverageTemperature']=temp_country['AverageTemperature'].fillna(temp_country['AverageTemperature'].mean())
temp_city = temp_country.groupby('City')['AverageTemperature'].mean()
print(temp_city.head())
plt.figure(figsize=(12,6))
plt.bar(temp_city.index,temp_city.values)
plt.xlabel('City')
plt.ylabel('Average Temperature')
plt.title('Average Temperature for Cities')
plt.xticks(rotation=45, ha='right')
plt.show()
# Out:
# City
# Aalborg            7.804410
# Adana             18.697150
# Afyonkarahisar    11.134219
# Aksaray           11.221643
# Alanya            18.211995
# Name: AverageTemperature, dtype: float64
# C:\Users\CVR\AppData\Local\Temp\ipykernel_14184\1581398098.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp_country['AverageTemperature']=temp_country['AverageTemperature'].fillna(temp_country['AverageTemperature'].mean())

# %%
import matplotlib.pyplot as plt
countries=df['Country'].unique()[:30]
temp_country=df[df['Country'].isin(countries)]
temp_country['AverageTemperature']=temp_country['AverageTemperature'].fillna(temp_country['AverageTemperature'].mean())
temp_city = temp_country.groupby('Country')['AverageTemperature'].mean()
print(temp_city.head())
plt.figure(figsize=(12,6))
plt.bar(temp_city.index,temp_city.values,color='lightgreen')
plt.xlabel('Countries')
plt.ylabel('Average Temperature')
plt.title('Average Temperature for Cities')
plt.xticks(rotation=45, ha='right')
plt.show()
# Out:
# C:\Users\CVR\AppData\Local\Temp\ipykernel_14184\2007510258.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp_country['AverageTemperature']=temp_country['AverageTemperature'].fillna(temp_country['AverageTemperature'].mean())
# Country
# Australia    16.694319
# Benin        25.781082
# Burma        25.621681
# Canada        5.493824
# China        12.579701
# Name: AverageTemperature, dtype: float64

# %%
import matplotlib.pyplot as plt
temperatures=df['AverageTemperature']
temperatures.dropna()
print(temperatures.head())
plt.figure(figsize=(12,6))
b=[5,10,15,20,25,30,35,40,45,50]
plt.hist(temperatures,bins=b,color='lightgreen',edgecolor='black')
plt.xlabel('Countries')
plt.ylabel('Average Temperature')
plt.title('Average Temperature for Cities')
plt.xticks(rotation=45, ha='right')
plt.show()
# Out:
# 0    6.068
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN
# Name: AverageTemperature, dtype: float64

# %%
df.isna().sum()
# Out:
# dt                                    0
# AverageTemperature               364130
# AverageTemperatureUncertainty    364130
# City                                  0
# Country                               0
# Latitude                              0
# Longitude                             0
# dtype: int64

# %%
import matplotlib.pyplot as plt
temperatures=df['AverageTemperature']
temperatures=temperatures.dropna()
print(temperatures.head())
plt.figure(figsize=(12,6))
plt.hist(temperatures,bins=50,color='magenta',edgecolor='black')
plt.xlabel('Temperature')
plt.ylabel('Frequency')
plt.title('Temperature Distribution')
plt.show()
# Out:
# 0     6.068
# 5     5.788
# 6    10.644
# 7    14.051
# 8    16.082
# Name: AverageTemperature, dtype: float64

# %%
df=df.dropna()

# %%
df.isna().sum()
# Out:
# dt                               0
# AverageTemperature               0
# AverageTemperatureUncertainty    0
# City                             0
# Country                          0
# Latitude                         0
# Longitude                        0
# dtype: int64

# %%
df.columns
# Out:
# Index(['dt', 'AverageTemperature', 'AverageTemperatureUncertainty', 'City',
#        'Country', 'Latitude', 'Longitude'],
#       dtype='object')

# %%
import matplotlib.pyplot as plt
x=df['AverageTemperature']
y=df['AverageTemperatureUncertainty']
plt.figure(figsize=(12,6))
plt.scatter(x,y,color='beige',marker='o',s=20,edgecolor='black')
plt.xlabel('Average Temperatures')
plt.ylabel('Average Temperature Uncertainity')
plt.title('Temperature Distribution')
plt.show()

# %%
import matplotlib.pyplot as plt
temp=df[df['Country']=='Togo']
x=temp['AverageTemperature']
y=temp['AverageTemperatureUncertainty']
plt.figure(figsize=(12,6))
plt.scatter(x,y,color='yellow',marker='o',s=20,edgecolor='black')
plt.xlabel('Average Temperatures')
plt.ylabel('Average Temperature Uncertainity')
plt.title('Temperature Distribution')
plt.show()

# %%
import matplotlib.pyplot as plt
temp=df[df['Country']=='Denmark'].copy()
temp['year'] = temp['dt'].dt.year
country_data=temp[['year','AverageTemperature']]
grouped_data =[ group['AverageTemperature'] for _, group in temp.groupby('year')]
years = sorted(temp['year'].unique())
print(avg_temp_city.head())
plt.figure(figsize=(12,6))
plt.boxplot(grouped_data,labels=years)
plt.xlabel('Year')
plt.ylabel('Average Temperature')
plt.title('Average Temperature over Years')
plt.show()
# Out:
# year
# 1743    6.221000
# 1744    9.147000
# 1745    0.060125
# 1750    8.808818
# 1751    8.188125
# Name: AverageTemperature, dtype: float64
# C:\Users\CVR\AppData\Local\Temp\ipykernel_14184\1538074797.py:8: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot(grouped_data,labels=years)

# %%
import matplotlib.pyplot as plt
country_data = df[df['Country'] == 'India'].copy()

country_data['Year'] = pd.to_datetime(country_data['dt']).dt.year.head(100)
temperature_data = country_data[['Year', 'AverageTemperature']]

plt.figure(figsize=(12, 6))
plt.boxplot(
    [temperature_data[temperature_data['Year'] == year]['AverageTemperature'] for year in temperature_data['Year'].unique()],
    labels=temperature_data['Year'].unique(),
    patch_artist=True,
    boxprops=dict(facecolor='purple', color='black'),
    medianprops=dict(color='yellow', linewidth=1.5),
    flierprops=dict(marker='o', color='red', alpha=0.5),
)

plt.title('Spread of Average Temperatures in the India (by Year)', fontsize=18)
plt.xlabel('Year', fontsize=14)
plt.ylabel('Average Temperature', fontsize=14)
plt.xticks(rotation=45)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()
# Out:
# C:\Users\CVR\AppData\Local\Temp\ipykernel_14184\2060327761.py:8: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot(
