# %%
import pandas as pd

# %%
clev=pd.read_csv('C:\\Users\\CVR\\Desktop\\6666coe\\clevelanda (1).csv')
clev.head()
# Out:
#    age  gender  cp  trestbps  chol  fps  restecg  thalach  exang  oldpeak  \
# 0   63       1   1       145   233    1        2      150      0      2.3
# 1   67       1   4       160   286    0        2      108      1      1.5
# 2   67       1   4       120   229    0        2      129      1      2.6
# 3   37       1   3       130   250    0        0      187      0      3.5
# 4   41       0   2       130   204    0        2      172      0      1.4
#
#    slope ca thal  class
# 0      3  0    6      0
# 1      2  3    3      2
# 2      2  2    7      1
# 3      3  0    3      0
# 4      1  0    3      0

# %%
clev.dtypes
# Out:
# age           int64
# gender        int64
# cp            int64
# trestbps      int64
# chol          int64
# fps           int64
# restecg       int64
# thalach       int64
# exang         int64
# oldpeak     float64
# slope         int64
# ca           object
# thal         object
# class         int64
# dtype: object

# %%
clev.shape
# Out:
# (303, 14)

# %%
clev.isna().sum()
# Out:
# age         0
# gender      0
# cp          0
# trestbps    0
# chol        0
# fps         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          0
# thal        0
# class       0
# dtype: int64

# %%
clev.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 303 entries, 0 to 302
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       303 non-null    int64
#  1   gender    303 non-null    int64
#  2   cp        303 non-null    int64
#  3   trestbps  303 non-null    int64
#  4   chol      303 non-null    int64
#  5   fps       303 non-null    int64
#  6   restecg   303 non-null    int64
#  7   thalach   303 non-null    int64
#  8   exang     303 non-null    int64
#  9   oldpeak   303 non-null    float64
#  10  slope     303 non-null    int64
#  11  ca        303 non-null    object
#  12  thal      303 non-null    object
#  13  class     303 non-null    int64
# dtypes: float64(1), int64(11), object(2)
# memory usage: 33.3+ KB

# %%
clev.iloc[:5,:5]
# Out:
#    age  gender  cp  trestbps  chol
# 0   63       1   1       145   233
# 1   67       1   4       160   286
# 2   67       1   4       120   229
# 3   37       1   3       130   250
# 4   41       0   2       130   204

# %%
clev['ca'].unique()
# Out:
# array(['0', '3', '2', '1', '?'], dtype=object)

# %%
clev['ca'].value_counts()
# Out:
# ca
# 0    176
# 1     65
# 2     38
# 3     20
# ?      4
# Name: count, dtype: int64

# %%
pip install plotly-express
# Out:
# ...
#   Using cached plotly_express-0.4.1-py2.py3-none-any.whl.metadata (1.7 kB)
# ...
#   Using cached statsmodels-0.14.4-cp311-cp311-win_amd64.whl.metadata (9.5 kB)
# ...
# Using cached plotly_express-0.4.1-py2.py3-none-any.whl (2.9 kB)
# Using cached statsmodels-0.14.4-cp311-cp311-win_amd64.whl (9.9 MB)
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import plotly.express as px

# %%
import matplotlib.pyplot as plt
plt.hist(clev['age'],color='blue',bins=15)
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.show()

# %%
pip install matplotlib
# Out:
# ...
#    ---------------------------------------- 0.0/8.0 MB ? eta -:--:--
#    ---------- ----------------------------- 2.1/8.0 MB 10.7 MB/s eta 0:00:01
#    --------------- ------------------------ 3.1/8.0 MB 7.4 MB/s eta 0:00:01
#    -------------------- ------------------- 4.2/8.0 MB 6.4 MB/s eta 0:00:01
#    -------------------------- ------------- 5.2/8.0 MB 6.0 MB/s eta 0:00:01
#    ------------------------------- -------- 6.3/8.0 MB 5.8 MB/s eta 0:00:01
#    ------------------------------------ --- 7.3/8.0 MB 5.7 MB/s eta 0:00:01
#    ---------------------------------------- 8.0/8.0 MB 5.5 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/2.2 MB ? eta -:--:--
#    ------------------ --------------------- 1.0/2.2 MB 5.0 MB/s eta 0:00:01
#    ------------------------------------- -- 2.1/2.2 MB 4.9 MB/s eta 0:00:01
#    ---------------------------------------- 2.2/2.2 MB 4.8 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/2.6 MB ? eta -:--:--
# ...

# %%
length=len(clev.columns)
print(length)
for i in range(0,length):
    print(clev.iloc[:,i].unique())
# Out:
# 14
# [63 67 37 41 56 62 57 53 44 52 48 54 49 64 58 60 50 66 43 40 69 59 42 55
#  61 65 71 51 46 45 39 68 47 34 35 29 70 77 38 74 76]
# [1 0]
# [1 4 3 2]
# [145 160 120 130 140 172 150 110 132 117 135 112 105 124 125 142 128 170
#  155 104 180 138 108 134 122 115 118 100 200  94 165 102 152 101 126 174
#  148 178 158 192 129 144 123 136 146 106 156 154 114 164]
# [233 286 229 250 204 236 268 354 254 203 192 294 256 263 199 168 239 275
#  266 211 283 284 224 206 219 340 226 247 167 230 335 234 177 276 353 243
#  225 302 212 330 175 417 197 198 290 253 172 273 213 305 216 304 188 282
#  185 232 326 231 269 267 248 360 258 308 245 270 208 264 321 274 325 235
#  257 164 141 252 255 201 222 260 182 303 265 309 307 249 186 341 183 407
#  217 288 220 209 227 261 174 281 221 205 240 289 318 298 564 246 322 299
#  300 293 277 214 207 223 160 394 184 315 409 244 195 196 126 313 259 200
#  262 215 228 193 271 210 327 149 295 306 178 237 218 242 319 166 180 311
# ...

# %%
for i in clev.columns:
    print(i,clev[i].unique())
# Out:
# age [63 67 37 41 56 62 57 53 44 52 48 54 49 64 58 60 50 66 43 40 69 59 42 55
#  61 65 71 51 46 45 39 68 47 34 35 29 70 77 38 74 76]
# gender [1 0]
# cp [1 4 3 2]
# trestbps [145 160 120 130 140 172 150 110 132 117 135 112 105 124 125 142 128 170
#  155 104 180 138 108 134 122 115 118 100 200  94 165 102 152 101 126 174
#  148 178 158 192 129 144 123 136 146 106 156 154 114 164]
# chol [233 286 229 250 204 236 268 354 254 203 192 294 256 263 199 168 239 275
#  266 211 283 284 224 206 219 340 226 247 167 230 335 234 177 276 353 243
#  225 302 212 330 175 417 197 198 290 253 172 273 213 305 216 304 188 282
#  185 232 326 231 269 267 248 360 258 308 245 270 208 264 321 274 325 235
#  257 164 141 252 255 201 222 260 182 303 265 309 307 249 186 341 183 407
#  217 288 220 209 227 261 174 281 221 205 240 289 318 298 564 246 322 299
#  300 293 277 214 207 223 160 394 184 315 409 244 195 196 126 313 259 200
#  262 215 228 193 271 210 327 149 295 306 178 237 218 242 319 166 180 311
# ...

# %%
import numpy as np
clev=clev.replace('?',np.nan)

# %%
clev['ca'].value_counts()
# Out:
# ca
# 0    176
# 1     65
# 2     38
# 3     20
# Name: count, dtype: int64

# %%
clev['ca']=clev['ca'].fillna(clev['ca'].mode())

# %%
clev['ca'].value_counts()
# Out:
# Series([], Name: count, dtype: int64)

# %%
clev.head()
# Out:
#    age  gender  cp  trestbps  chol  fps  restecg  thalach  exang  oldpeak  \
# 0   63       1   1       145   233    1        2      150      0      2.3
# 1   67       1   4       160   286    0        2      108      1      1.5
# 2   67       1   4       120   229    0        2      129      1      2.6
# 3   37       1   3       130   250    0        0      187      0      3.5
# 4   41       0   2       130   204    0        2      172      0      1.4
#
#    slope    ca thal  class
# 0      3  None    6      0
# 1      2  None    3      2
# 2      2  None    7      1
# 3      3  None    3      0
# 4      1  None    3      0

# %%
df=pd.read_csv('C:\\Users\\CVR\\Desktop\\6666coe\\clevelanda (1).csv')
df.head()
# Out:
#    age  gender  cp  trestbps  chol  fps  restecg  thalach  exang  oldpeak  \
# 0   63       1   1       145   233    1        2      150      0      2.3
# 1   67       1   4       160   286    0        2      108      1      1.5
# 2   67       1   4       120   229    0        2      129      1      2.6
# 3   37       1   3       130   250    0        0      187      0      3.5
# 4   41       0   2       130   204    0        2      172      0      1.4
#
#    slope ca thal  class
# 0      3  0    6      0
# 1      2  3    3      2
# 2      2  2    7      1
# 3      3  0    3      0
# 4      1  0    3      0

# %%
df['ca'].value_counts()
# Out:
# ca
# 0    176
# 1     65
# 2     38
# 3     20
# ?      4
# Name: count, dtype: int64

# %%
import numpy as np
df=df.replace('?',np.nan)
df['ca'].value_counts()
# Out:
# ca
# 0    176
# 1     65
# 2     38
# 3     20
# Name: count, dtype: int64

# %%
pd.to_numeric(df['ca'], errors='coerce').mean()
# Out:
# 0.6722408026755853

# %%
df
# Out:
#      age  gender  cp  trestbps  chol  fps  restecg  thalach  exang  oldpeak  \
# 0     63       1   1       145   233    1        2      150      0      2.3
# 1     67       1   4       160   286    0        2      108      1      1.5
# 2     67       1   4       120   229    0        2      129      1      2.6
# 3     37       1   3       130   250    0        0      187      0      3.5
# 4     41       0   2       130   204    0        2      172      0      1.4
# ..   ...     ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   45       1   1       110   264    0        0      132      0      1.2
# 299   68       1   4       144   193    1        0      141      0      3.4
# 300   57       1   4       130   131    0        0      115      1      1.2
# 301   57       0   2       130   236    0        2      174      0      0.0
# 302   38       1   3       138   175    0        0      173      0      0.0
#
#      slope   ca thal  class
# ...

# %%
df['ca']=df['ca'].fillna(df['ca'].mode()[0])
df['ca'].value_counts()
# Out:
# ca
# 0    180
# 1     65
# 2     38
# 3     20
# Name: count, dtype: int64

# %%
df
# Out:
#      age  gender  cp  trestbps  chol  fps  restecg  thalach  exang  oldpeak  \
# 0     63       1   1       145   233    1        2      150      0      2.3
# 1     67       1   4       160   286    0        2      108      1      1.5
# 2     67       1   4       120   229    0        2      129      1      2.6
# 3     37       1   3       130   250    0        0      187      0      3.5
# 4     41       0   2       130   204    0        2      172      0      1.4
# ..   ...     ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   45       1   1       110   264    0        0      132      0      1.2
# 299   68       1   4       144   193    1        0      141      0      3.4
# 300   57       1   4       130   131    0        0      115      1      1.2
# 301   57       0   2       130   236    0        2      174      0      0.0
# 302   38       1   3       138   175    0        0      173      0      0.0
#
#      slope ca thal  class
# 0        3  0    6      0
# ...

# %%
df['thal'].isna().sum()
# Out:
# 2

# %%
df.dtypes
# Out:
# age           int64
# gender        int64
# cp            int64
# trestbps      int64
# chol          int64
# fps           int64
# restecg       int64
# thalach       int64
# exang         int64
# oldpeak     float64
# slope         int64
# ca           object
# thal         object
# class         int64
# dtype: object

# %%
df['thal']=df['thal'].fillna(pd.to_numeric(df['thal'], errors='coerce').mean())
print(df['thal'].value_counts())
print(df['thal'].isna().sum())
# Out:
# thal
# 3           166
# 7           117
# 6            18
# 4.734219      2
# Name: count, dtype: int64
# 0

# %%
df.dtypes
# Out:
# age           int64
# gender        int64
# cp            int64
# trestbps      int64
# chol          int64
# fps           int64
# restecg       int64
# thalach       int64
# exang         int64
# oldpeak     float64
# slope         int64
# ca           object
# thal         object
# class         int64
# dtype: object

# %%
df.isna().sum()
# Out:
# age         0
# gender      0
# cp          0
# trestbps    0
# chol        0
# fps         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          0
# thal        0
# class       0
# dtype: int64
