# %%
import pandas as pd

# %%
df=pd.read_csv("C:\\Users\\CVR\\Desktop\\6666coe\\Aishwarya6666COE\\weight_height.csv")
df.head()
# Out:
#    Weight  Height
# 0      72     197
# 1      57     181
# 2      68     157
# 3      73     186
# 4      75     183

# %%
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(12,6))
sns.scatterplot(x=df['Weight'], y=df['Height'],color='blue')
plt.xlabel('weight')
plt.ylabel('Height')

plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(12,6))
plt.scatter(df['Weight'],df['Height'],color='beige',edgecolor='black')
plt.xlabel('weight')
plt.ylabel('Height')
plt.show()

# %%
df.corr()
sns.heatmap(df.corr())
# Out:
# <Axes: >

# %%
plt.figure(figsize=(12,6))
sns.pairplot(data=df, diag_kind="kde")
plt.xlabel('weight')
plt.ylabel('Height')
plt.show()

# %%
from sklearn.model_selection import train_test_split
x=df['Weight'].values.reshape(-1,1)
y=df['Height'].values
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size = 0.20,random_state=42)

# %%
type(x)
# Out:
# numpy.ndarray

# %%
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

scaler.fit_transform(x_train)
 
x_test = scaler.transform(x_test)
 
regression = LinearRegression(n_jobs=-1)
regression.fit(x_train, y_train)
 
print("Coefficient or slope",regression.coef_)

print("Intercept",regression.intercept_)
 
## plot Training data plot best fit line

scatter = plt.scatter(x_train,y_train)

plt.show(scatter)
 
slope_of_best_fit = plt.plot(x_train,regression.predict(x_train))
 
plt.show(slope_of_best_fit)
# Out:
# Coefficient or slope [0.21696684]
# Intercept 157.41906847783034
